# %%
import pandas as pd

# %%
df = pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
cols = list(df.columns)
df = df[cols[0:2]+cols[1:3]+[cols[-1]]+cols[2:]]
df.head()
# Out:
#    Pregnancies  Glucose  Glucose  BloodPressure  Outcome  BloodPressure  \
# 0            6      148      148             72        1             72
# 1            1       85       85             66        0             66
# 2            8      183      183             64        1             64
# 3            1       89       89             66        0             66
# 4            0      137      137             40        1             40
#
#    SkinThickness  Insulin   BMI  DiabetesPedigreeFunction  Age  Outcome
# 0             35        0  33.6                     0.627   50        1
# 1             29        0  26.6                     0.351   31        0
# 2              0        0  23.3                     0.672   32        1
# 3             23       94  28.1                     0.167   21        0
# 4             35      168  43.1                     2.288   33        1

# %%
x=df.iloc[:,:-2]
y=df.iloc[:,-2:]
newdf = pd.concat([y,x],axis=1)

# %%
newdf
# Out:
#      Age  Outcome  Pregnancies  Glucose  Glucose  BloodPressure  Outcome  \
# 0     50        1            6      148      148             72        1
# 1     31        0            1       85       85             66        0
# 2     32        1            8      183      183             64        1
# 3     21        0            1       89       89             66        0
# 4     33        1            0      137      137             40        1
# ..   ...      ...          ...      ...      ...            ...      ...
# 763   63        0           10      101      101             76        0
# 764   27        0            2      122      122             70        0
# 765   30        0            5      121      121             72        0
# 766   47        1            1      126      126             60        1
# 767   23        0            1       93       93             70        0
#
#      BloodPressure  SkinThickness  Insulin   BMI  DiabetesPedigreeFunction
# ...
